# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
df = pd.read_csv("./201609-citibike-tripdata.csv")

# %%
list(df.columns.values)
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
df
# Out:
#          tripduration           starttime            stoptime  \
# 0                 975   9/1/2016 00:00:02   9/1/2016 00:16:18
# 1                1220   9/1/2016 00:00:04   9/1/2016 00:20:25
# 2                 308   9/1/2016 00:00:19   9/1/2016 00:05:27
# 3                 250   9/1/2016 00:00:25   9/1/2016 00:04:35
# 4                 439   9/1/2016 00:00:25   9/1/2016 00:07:45
# 5                 730   9/1/2016 00:00:39   9/1/2016 00:12:50
# 6                 188   9/1/2016 00:00:40   9/1/2016 00:03:49
# 7                 776   9/1/2016 00:00:48   9/1/2016 00:13:44
# 8                 622   9/1/2016 00:00:48   9/1/2016 00:11:11
# 9                 756   9/1/2016 00:00:50   9/1/2016 00:13:27
# 10                186   9/1/2016 00:00:53   9/1/2016 00:04:00
# 11               1246   9/1/2016 00:00:52   9/1/2016 00:21:39
# 12               1445   9/1/2016 00:00:52   9/1/2016 00:24:58
# 13               1435   9/1/2016 00:00:56   9/1/2016 00:24:52
# ...

# %%
df.shape
# Out:
# (1648856, 15)

# %%
df['start station name'].value_counts().head(10)
# Out:
# Pershing Square North     16556
# West St & Chambers St     13039
# Cooper Square & E 7 St    12982
# E 17 St & Broadway        11032
# Broadway & E 22 St        10762
# W 21 St & 6 Ave           10649
# Central Park S & 6 Ave    10512
# 12 Ave & W 40 St          10277
# Broadway & E 14 St         9624
# 8 Ave & W 33 St            9460
# Name: start station name, dtype: int64

# %%
df['end station name'].value_counts().head(10)
# Out:
# Pershing Square North     16215
# West St & Chambers St     14082
# Cooper Square & E 7 St    13077
# Broadway & E 22 St        11672
# E 17 St & Broadway        11205
# 12 Ave & W 40 St          10865
# W 21 St & 6 Ave           10766
# Central Park S & 6 Ave    10121
# Broadway & E 14 St         9606
# W 20 St & 11 Ave           9598
# Name: end station name, dtype: int64

# %%
d1 =df['starttime'].str.split(pat=None, n=-1, expand=False).tolist()
d1[0]
# Out:
# ['9/1/2016', '00:00:02']

# %%
d2 = pd.DataFrame(d1, columns = "date time".split())
d2.head(5)
# Out:
#        date      time
# 0  9/1/2016  00:00:02
# 1  9/1/2016  00:00:04
# 2  9/1/2016  00:00:19
# 3  9/1/2016  00:00:25
# 4  9/1/2016  00:00:25

# %%
df['starttime2'] = d2['time']
df
# Out:
#          tripduration           starttime            stoptime  \
# 0                 975   9/1/2016 00:00:02   9/1/2016 00:16:18
# 1                1220   9/1/2016 00:00:04   9/1/2016 00:20:25
# 2                 308   9/1/2016 00:00:19   9/1/2016 00:05:27
# 3                 250   9/1/2016 00:00:25   9/1/2016 00:04:35
# 4                 439   9/1/2016 00:00:25   9/1/2016 00:07:45
# 5                 730   9/1/2016 00:00:39   9/1/2016 00:12:50
# 6                 188   9/1/2016 00:00:40   9/1/2016 00:03:49
# 7                 776   9/1/2016 00:00:48   9/1/2016 00:13:44
# 8                 622   9/1/2016 00:00:48   9/1/2016 00:11:11
# 9                 756   9/1/2016 00:00:50   9/1/2016 00:13:27
# 10                186   9/1/2016 00:00:53   9/1/2016 00:04:00
# 11               1246   9/1/2016 00:00:52   9/1/2016 00:21:39
# 12               1445   9/1/2016 00:00:52   9/1/2016 00:24:58
# 13               1435   9/1/2016 00:00:56   9/1/2016 00:24:52
# ...

# %%
df2 = df[df['starttime2'] < '05:00:00']
df2
# Out:
#          tripduration           starttime            stoptime  \
# 0                 975   9/1/2016 00:00:02   9/1/2016 00:16:18
# 1                1220   9/1/2016 00:00:04   9/1/2016 00:20:25
# 2                 308   9/1/2016 00:00:19   9/1/2016 00:05:27
# 3                 250   9/1/2016 00:00:25   9/1/2016 00:04:35
# 4                 439   9/1/2016 00:00:25   9/1/2016 00:07:45
# 5                 730   9/1/2016 00:00:39   9/1/2016 00:12:50
# 6                 188   9/1/2016 00:00:40   9/1/2016 00:03:49
# 7                 776   9/1/2016 00:00:48   9/1/2016 00:13:44
# 8                 622   9/1/2016 00:00:48   9/1/2016 00:11:11
# 9                 756   9/1/2016 00:00:50   9/1/2016 00:13:27
# 10                186   9/1/2016 00:00:53   9/1/2016 00:04:00
# 11               1246   9/1/2016 00:00:52   9/1/2016 00:21:39
# 12               1445   9/1/2016 00:00:52   9/1/2016 00:24:58
# 13               1435   9/1/2016 00:00:56   9/1/2016 00:24:52
# ...

# %%
df2.to_csv("201609-new.csv")

# %%
df2.shape
# Out:
# (34176, 16)

# %%
df2['start station name'].value_counts().head(10)
# Out:
# Allen St & Stanton St      442
# Cooper Square & E 7 St     424
# W 4 St & 7 Ave S           420
# Carmine St & 6 Ave         366
# 9 Ave & W 18 St            348
# St Marks Pl & 2 Ave        307
# Allen St & Rivington St    287
# W 13 St & Hudson St        264
# St Marks Pl & 1 Ave        264
# LaGuardia Pl & W 3 St      261
# Name: start station name, dtype: int64

# %%
df2['end station name'].value_counts().head(10)
# Out:
# Cooper Square & E 7 St    317
# St Marks Pl & 2 Ave       287
# E 10 St & Avenue A        275
# Allen St & Stanton St     267
# E 20 St & 2 Ave           260
# W 41 St & 8 Ave           251
# E 13 St & Avenue A        245
# Carmine St & 6 Ave        243
# 8 Ave & W 33 St           237
# 9 Ave & W 45 St           216
# Name: end station name, dtype: int64

# %%
df3 = df2.groupby('start station name').agg('count')

# %%
df3.to_csv("stations.csv")

# %%
df2['gender'].value_counts()
# Out:
# 1    24356
# 2     5003
# 0     4817
# Name: gender, dtype: int64

# %%
dfw4st = df2[df2['start station name'] == 'W 4 St & 7 Ave S']

# %%
dfw4st.to_csv("w4st.csv")

# %%
dfw4st_count = dfw4st.groupby('end station name').agg('count')

# %%
dfw4st_count.to_csv("w4st_count.csv")

# %%
15931/34176
# Out:
# 0.4661458333333333
